# %%
import matplotlib.pyplot as plt 
import pickle 
import matplotlib as mpl 
import numpy as np

# %%
with open("DDPG_adaptive_reward_factor.pkl", "rb") as f: 
    data = pickle.load(f)

# %%
# histories = data["test_history"]
# rewards = data["rewards"]

histories = {} 

fig = plt.figure(figsize=(14, 6))
# cmap = plt.get_cmap('jet')
# norm = mpl.colors.Normalize(vmin=1, vmax=150)

# plt.subplot(1, 2, 1)
# for i, SOC_trajectory in enumerate(SOC_trajectories): 
#     color = cmap(float(i) / len(SOC_trajectories))
#     plt.plot(SOC_trajectory, c=color)
#     plt.ylabel("SOC", fontsize=14)
#     plt.xlabel("Time [s]", fontsize=14)
#     plt.title("SOC Trajectories with episodes", fontsize=14)
# plt.grid() 
for RF, dictionary in data.items(): 
    histories[RF] = dictionary["test_history"]

for RF, history in histories.items():
    plt.figure() 
    history = history[-5:]
    for i, history_temp in enumerate(history): 
        SOC_trajectory = history_temp["SOC"]
        if i == 0: 
            plt.plot(SOC_trajectory, linewidth=2)
        else: 
            plt.plot(SOC_trajectory,linewidth=2)
    plt.legend(fontsize=16)
    plt.ylabel("SOC", fontsize=16)
    plt.xlabel("Time [s]", fontsize=16)
    plt.title("Reward factor = {:.3f}".format(RF), fontsize=16)
    plt.grid()
    plt.savefig("SOC_trajectory_Reward_factor = {:.3f}.png".format(RF))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
with open("degradation_adaptive_reward_factor.pkl", "rb") as f: 
    data = pickle.load(f)
    
# histories = data["test_history"]
# rewards = data["rewards"]

histories = {} 

fig = plt.figure(figsize=(14, 6))
# cmap = plt.get_cmap('jet')
# norm = mpl.colors.Normalize(vmin=1, vmax=150)

# plt.subplot(1, 2, 1)
# for i, SOC_trajectory in enumerate(SOC_trajectories): 
#     color = cmap(float(i) / len(SOC_trajectories))
#     plt.plot(SOC_trajectory, c=color)
#     plt.ylabel("SOC", fontsize=14)
#     plt.xlabel("Time [s]", fontsize=14)
#     plt.title("SOC Trajectories with episodes", fontsize=14)
# plt.grid() 
for RF, dictionary in data.items(): 
    histories[RF] = dictionary["train_history"]

for RF, history in histories.items():
    plt.figure() 
    history = history[-5:]
    for i, history_temp in enumerate(history): 
        SOC_trajectory = history_temp["SOC"]
        if i == 0: 
            plt.plot(SOC_trajectory, linewidth=2)
        else: 
            plt.plot(SOC_trajectory,linewidth=2)
    plt.legend(fontsize=16)
    plt.ylabel("SOC", fontsize=16)
    plt.xlabel("Time [s]", fontsize=16)
    plt.title("Reward factor = {:.3f}".format(RF), fontsize=16)
    plt.grid()
    plt.savefig("SOC_trajectory_Reward_factor = {:.3f}.png".format(RF))
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(14, 6))

cmap = plt.get_cmap('jet')
norm = mpl.colors.Normalize(vmin=1, vmax=150)

plt.subplot(1, 2, 1)
for i, SOC_trajectory in enumerate(SOC_trajectories): 
    color = cmap(float(i) / len(SOC_trajectories))
    plt.plot(SOC_trajectory, c=color)
    plt.ylabel("SOC", fontsize=14)
    plt.xlabel("Time [s]", fontsize=14)
    plt.title("SOC Trajectories with episodes", fontsize=14)
plt.grid() 

plt.subplot(1, 2, 2)
for i, fuel_trajectory in enumerate(fuel_trajectories): 
    color = cmap(float(i) / len(SOC_trajectories))
    fuel_trajectory = np.cumsum(fuel_trajectory)
    plt.plot(fuel_trajectory, c=color)
    plt.ylabel("Cumulative fuel consumption [g]", fontsize=14)
    plt.xlabel("Time [s]", fontsize=14)
    plt.title("Cumulative fuel consumption with episodes", fontsize=14)
plt.grid() 
    
fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap))
plt.savefig("training process.png")

# %%
plt.figure(figsize=(8, 6))
plt.plot(rewards, linewidth=3)
plt.ylabel("Episodic Rewards", fontsize=14)
plt.xlabel("Episodes", fontsize=14)
plt.title("Episodic Rewards with episode", fontsize=14)
plt.grid() 
plt.savefig("Episodic Rewards.png")
